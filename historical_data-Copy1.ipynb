# %%
#initiate imports

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime,timezone,timedelta
import json
import math
from scipy.stats import linregress
import cbpro

# %% [markdown]
# --------------------------------------------------------------------------------------

# %%
#api for nomics https://api.nomics.com/
apk="m_9386cac54693578a1cbfb3729a22c0c080769888"

# %%
#NOMICS is 8 hours ahead
#exchange history
def new_request(crypto,my_limit,start_date,start_time):
    url = f'https://api.nomics.com/v1/trades?key={apk}&exchange=binance&market={crypto}USDT&limit={my_limit}&order=asc&from={start_date}{start_time}'
    return requests.get(url).json()

# %%
#this will be a function to update utc time
def add_second_nomics(df):
    my_last_time=str(df.iloc[-1]['timestamp'])
    my_last_time=pd.to_datetime(my_last_time,utc=True)+ timedelta(seconds=2)
    my_last_time=str(my_last_time)

    parse=my_last_time.split(' ')
    parse_time=parse[1].split(':')
    #then if time is less than time
    parse_time
    my_new_time='T'+parse_time[0]+'%3A'+parse_time[1]+'%3A'+parse_time[2].split(".")[0].split('+')[0]+'Z'
    my_new_date=parse[0]
    my_new_utc=my_new_date+'T'+parse_time[0]+':'+parse_time[1]+':'+parse_time[2].split(".")[0].split('+')[0]+'Z'
    
    #print(parse_time)
    return [my_new_time,my_new_date,my_new_utc]

# %%
def get_historical_data(the_crypto,the_date,the_time,end_time):

    #build data frame for expressed time and crypto
    #UCT time is 8 hours ahead, so this would be 02:00:00am PST
    request_num=2

    crypto=the_crypto
    start_time=the_time
    start_date=the_date
    my_limit=2500
    my_df_lenght=my_limit

    #the initial request
    df=pd.DataFrame(new_request(crypto,my_limit,start_date,start_time))
    print(f'request: {1}')


    #loop while conditions are true
    my_conditions=True
    my_limit=len(df)


    while my_conditions:
        
        start_time,start_date,utc_time=add_second_nomics(df)
        if (pd.to_datetime(utc_time)<pd.to_datetime(end_time)):
            my_conditions=True  
        else:
            my_conditions=False

        if (my_conditions):
            print(start_time)
            new_df=pd.DataFrame(new_request(crypto,my_limit,start_date,start_time))
            df=pd.concat([df, new_df])
            df.reset_index(inplace=True)
            del df['index']
            my_df_lenght=len(df)
            print(f'request: {request_num} and new df lenght is {my_df_lenght}')
            request_num=request_num+1
            
        

    return df

# %%
#!!!!!!!!!!!!!!!!!!!!  RUN THIS FOR HISTORIAL NOMIC  !!!!!!!!!!!!!!!!!!!!
#is 8 hours ahead
df=get_historical_data('BTC','2021-12-12','T20%3A30%3A00Z','2021-12-13T00:30:02.000Z')
start_time,end_time,utc_time=add_second_nomics(df)
# Out:
# request: 1
# T20%3A36%3A44Z
# request: 2 and new df lenght is 5000
# T20%3A44%3A47Z
# request: 3 and new df lenght is 7500
# T20%3A51%3A32Z
# request: 4 and new df lenght is 10000
# T20%3A58%3A49Z
# request: 5 and new df lenght is 12500
# T21%3A05%3A03Z
# request: 6 and new df lenght is 15000
# T21%3A11%3A08Z
# request: 7 and new df lenght is 17500
# T21%3A18%3A36Z
# request: 8 and new df lenght is 20000
# T21%3A26%3A55Z
# request: 9 and new df lenght is 22500
# T21%3A34%3A05Z
# request: 10 and new df lenght is 25000
# T21%3A38%3A52Z
# request: 11 and new df lenght is 27500
# T21%3A42%3A02Z
# request: 12 and new df lenght is 30000
# T21%3A45%3A19Z
# request: 13 and new df lenght is 32500
# T21%3A50%3A50Z
# request: 14 and new df lenght is 35000
# T21%3A54%3A08Z
# request: 15 and new df lenght is 37500
# T21%3A59%3A53Z
# request: 16 and new df lenght is 40000
# T22%3A06%3A00Z
# request: 17 and new df lenght is 42500
# T22%3A12%3A57Z
# request: 18 and new df lenght is 45000
# T22%3A18%3A58Z
# request: 19 and new df lenght is 47500
# T22%3A25%3A40Z
# request: 20 and new df lenght is 50000
# T22%3A31%3A32Z
# request: 21 and new df lenght is 52500
# T22%3A39%3A01Z
# request: 22 and new df lenght is 55000
# T22%3A44%3A13Z
# request: 23 and new df lenght is 57500
# T22%3A51%3A27Z
# request: 24 and new df lenght is 60000
# T22%3A58%3A29Z
# request: 25 and new df lenght is 62500
# T23%3A01%3A19Z
# request: 26 and new df lenght is 65000
# T23%3A06%3A02Z
# request: 27 and new df lenght is 67500
# T23%3A13%3A41Z
# request: 28 and new df lenght is 70000
# T23%3A23%3A03Z
# request: 29 and new df lenght is 72500
# T23%3A31%3A37Z
# request: 30 and new df lenght is 75000
# T23%3A38%3A46Z
# request: 31 and new df lenght is 77500
# T23%3A44%3A37Z
# request: 32 and new df lenght is 80000
# T23%3A51%3A26Z
# request: 33 and new df lenght is 82500
# T23%3A59%3A46Z
# request: 34 and new df lenght is 85000
# T00%3A03%3A49Z
# request: 35 and new df lenght is 87500
# T00%3A09%3A29Z
# request: 36 and new df lenght is 90000
# T00%3A16%3A09Z
# request: 37 and new df lenght is 92500
# T00%3A21%3A55Z
# request: 38 and new df lenght is 95000
# T00%3A25%3A18Z
# request: 39 and new df lenght is 97500
# T00%3A26%3A30Z
# request: 40 and new df lenght is 100000
# T00%3A28%3A34Z
# request: 41 and new df lenght is 102500

# %%
my_x=df.price.astype(float)
plt.plot(my_x)

# %% [markdown]
# --------------------------------------------------------------------------------------

# %%
#!!!!!!!!!!!!!!!!!!!!  RUN THIS FOR HISTORIAL COINBASE  !!!!!!!!!!!!!!!!!!!!

#COINBASE
#exchange history 20210404T040404Z
#four hours behind
request_num=0
c = cbpro.PublicClient()

#change these to modify
the_start='2021-11-16T20:00:00'
finish_date='2021-12-17T06:00:00'
crypto='BTC-USDT'

#breaks it down to 1 hour searches
the_end=str(pd.to_datetime(the_start)+timedelta(hours=10))

#run through it once
historical = pd.DataFrame(c.get_product_historic_rates(product_id=crypto, start=the_start,
                                                       end=the_end, granularity=300))
historical.columns= ["Date","Open","High","Low","Close","Volume"]
historical['Date'] = pd.to_datetime(historical['Date'], unit='s')
historical.set_index('Date', inplace=True)
historical.sort_values(by='Date', ascending=True, inplace=True)

#loop through until finish is met
date_reached=False
while date_reached==False:
    if (historical.iloc[-1].name<pd.to_datetime(finish_date)):
            the_start=(historical.iloc[-1].name+timedelta(minutes=5))
            the_end=(historical.iloc[-1].name+timedelta(hours=10))
            new_df=pd.DataFrame(c.get_product_historic_rates(product_id=crypto, start=str(the_start),
                                                             end=str(the_end), granularity=300))
            new_df.columns= ["Date","Open","High","Low","Close","Volume"]
            new_df['Date'] = pd.to_datetime(new_df['Date'], unit='s')
            new_df.set_index('Date', inplace=True)
            new_df.sort_values(by='Date', ascending=True, inplace=True)
            historical=pd.concat([historical, new_df])
            my_df_lenght=len(historical)
            print(f'request: {request_num} and new df lenght is {my_df_lenght}')
            request_num=request_num+1
    else:
        date_reached=True
# Out:
# request: 0 and new df lenght is 241
# request: 1 and new df lenght is 361
# request: 2 and new df lenght is 481
# request: 3 and new df lenght is 601
# request: 4 and new df lenght is 721
# request: 5 and new df lenght is 841
# request: 6 and new df lenght is 961
# request: 7 and new df lenght is 1081
# request: 8 and new df lenght is 1201
# request: 9 and new df lenght is 1321
# request: 10 and new df lenght is 1441
# request: 11 and new df lenght is 1561
# request: 12 and new df lenght is 1681
# request: 13 and new df lenght is 1801
# request: 14 and new df lenght is 1921
# request: 15 and new df lenght is 2041
# request: 16 and new df lenght is 2151
# request: 17 and new df lenght is 2271
# request: 18 and new df lenght is 2391
# request: 19 and new df lenght is 2511
# request: 20 and new df lenght is 2631
# request: 21 and new df lenght is 2751
# request: 22 and new df lenght is 2871
# request: 23 and new df lenght is 2991
# request: 24 and new df lenght is 3111
# request: 25 and new df lenght is 3231
# request: 26 and new df lenght is 3351
# request: 27 and new df lenght is 3471
# request: 28 and new df lenght is 3591
# request: 29 and new df lenght is 3711
# request: 30 and new df lenght is 3831
# request: 31 and new df lenght is 3951
# request: 32 and new df lenght is 4071
# request: 33 and new df lenght is 4191
# request: 34 and new df lenght is 4311
# request: 35 and new df lenght is 4431
# request: 36 and new df lenght is 4551
# request: 37 and new df lenght is 4671
# request: 38 and new df lenght is 4791
# request: 39 and new df lenght is 4911
# request: 40 and new df lenght is 5031
# request: 41 and new df lenght is 5151
# request: 42 and new df lenght is 5271
# request: 43 and new df lenght is 5391
# request: 44 and new df lenght is 5511
# request: 45 and new df lenght is 5631
# request: 46 and new df lenght is 5751
# request: 47 and new df lenght is 5871
# request: 48 and new df lenght is 5991
# request: 49 and new df lenght is 6111
# request: 50 and new df lenght is 6231
# request: 51 and new df lenght is 6351
# request: 52 and new df lenght is 6471
# request: 53 and new df lenght is 6591
# request: 54 and new df lenght is 6711
# request: 55 and new df lenght is 6831
# request: 56 and new df lenght is 6951
# request: 57 and new df lenght is 7071
# request: 58 and new df lenght is 7191
# request: 59 and new df lenght is 7311
# request: 60 and new df lenght is 7431
# request: 61 and new df lenght is 7551
# request: 62 and new df lenght is 7671
# request: 63 and new df lenght is 7791
# request: 64 and new df lenght is 7911
# request: 65 and new df lenght is 8031
# request: 66 and new df lenght is 8151
# request: 67 and new df lenght is 8271
# request: 68 and new df lenght is 8391
# request: 69 and new df lenght is 8511
# request: 70 and new df lenght is 8631
# request: 71 and new df lenght is 8751

# %%
historical
# Out:
#       level_0  index                Date      Open      High       Low  \
# 0           0      0 2021-11-16 20:00:00  59893.35  60188.69  60188.68
# 1           1      1 2021-11-16 20:05:00  59979.60  60159.92  59997.95
# 2           2      2 2021-11-16 20:10:00  59837.59  60007.35  59987.24
# 3           3      3 2021-11-16 20:15:00  59600.89  59902.56  59902.56
# 4           4      4 2021-11-16 20:20:00  59708.14  59876.64  59771.78
# ...       ...    ...                 ...       ...       ...       ...
# 8746     8746   8746 2021-12-17 05:40:00  47601.14  47691.02  47691.02
# 8747     8747   8747 2021-12-17 05:45:00  47632.71  47694.31  47644.53
# 8748     8748   8748 2021-12-17 05:50:00  47622.27  47704.96  47632.37
# 8749     8749   8749 2021-12-17 05:55:00  47670.71  47730.92  47674.62
# 8750     8750   8750 2021-12-17 06:00:00  47707.69  47745.68  47726.96
#
#          Close    Volume
# 0     59992.99  0.704041
# 1     60030.96  1.263909
# 2     59905.54  7.138614
# 3     59770.55  3.807446
# 4     59711.45  0.899153
# ...        ...       ...
# 8746  47639.36  0.197613
# 8747  47632.71  0.774670
# 8748  47704.96  0.057973
# 8749  47730.92  0.050571
# 8750  47707.69  0.431999
#
# [8751 rows x 8 columns]

# %%
#save the csv
#historical.to_csv('BTC_2021_11_12_coinbase.csv')

# %%
#historical2=historical
#historical2.reset_index(inplace=True) - changed to numbers instead of dates
x = df.index
#x=np.arange(len(historical))
y = df.High
slope, intercept, r_value, p_value, std_err = linregress(x, y)

regress_values=x*slope+intercept
plt.plot(y)
plt.plot(x,regress_values,'-r')
plt.plot(x,regress_values*.965,'-g')
plt.plot(x,regress_values*1.035,'-y')

# %%
trunc_df=pd.read_csv("BTC_2021_11_12_coinbase.csv").iloc[0:244] #12 hours
#historical2=historical
#historical2.reset_index(inplace=True) - changed to numbers instead of dates
x = trunc_df.index
#x=np.arange(len(historical))
y = trunc_df.High
slope, intercept, r_value, p_value, std_err = linregress(x, y)

regress_values=x*slope+intercept
plt.plot(y)
plt.plot(x,regress_values,'-r')
plt.plot(x,regress_values*.99,'-g')
plt.plot(x,regress_values*1.01,'-y')

slope
# Out:
# -0.5643290542689433

# %%
window = np.delete(window, (0), axis=0)
window = np.append(window, 2)
window
# Out:
# array([5.972435e+04, 5.967372e+04, 5.940506e+04, 5.959239e+04,
#        5.964058e+04, 5.977561e+04, 6.019179e+04, 6.059415e+04,
#        6.065284e+04, 6.090808e+04, 6.078059e+04, 6.063307e+04,
#        6.066003e+04, 6.053583e+04, 6.068173e+04, 6.047407e+04,
#        6.041591e+04, 6.052542e+04, 6.057570e+04, 6.058119e+04,
#        6.062092e+04, 6.060791e+04, 6.064214e+04, 6.082387e+04,
#        6.111672e+04, 6.094201e+04, 6.074234e+04, 6.071220e+04,
#        6.068601e+04, 6.068194e+04, 6.066884e+04, 6.063949e+04,
#        6.061400e+04, 6.047640e+04, 6.046717e+04, 6.047304e+04,
#        6.045537e+04, 6.039175e+04, 6.033487e+04, 6.035174e+04,
#        6.023798e+04, 6.025278e+04, 6.019220e+04, 6.027053e+04,
#        6.040527e+04, 6.028054e+04, 5.988420e+04, 5.985874e+04,
#        5.996205e+04, 6.002289e+04, 5.994248e+04, 5.975085e+04,
#        5.968458e+04, 5.981847e+04, 5.988885e+04, 5.968508e+04,
#        5.979475e+04, 5.983379e+04, 5.986693e+04, 6.018239e+04,
#        6.025169e+04, 6.020667e+04, 6.009201e+04, 6.011940e+04,
#        5.975312e+04, 5.963633e+04, 5.942409e+04, 5.946388e+04,
#        5.953342e+04, 5.952268e+04, 5.961493e+04, 5.966213e+04,
#        5.972042e+04, 5.962985e+04, 5.958399e+04, 5.944751e+04,
#        5.949146e+04, 5.944638e+04, 5.953152e+04, 5.935255e+04,
#        5.909075e+04, 5.893783e+04, 5.898065e+04, 5.950030e+04,
#        5.974264e+04, 5.956178e+04, 5.944313e+04, 5.940100e+04,
#        5.949422e+04, 5.926188e+04, 5.917850e+04, 5.918681e+04,
#        5.894448e+04, 5.888397e+04, 5.919976e+04, 5.930584e+04,
#        5.942193e+04, 5.931598e+04, 5.946227e+04, 5.924162e+04,
#        5.912419e+04, 5.946407e+04, 5.955952e+04, 5.954723e+04,
#        5.949944e+04, 5.957959e+04, 5.967113e+04, 5.965923e+04,
#        5.960697e+04, 5.972428e+04, 5.972702e+04, 5.981169e+04,
#        5.953724e+04, 5.966324e+04, 5.969623e+04, 5.970777e+04,
#        5.953893e+04, 5.951303e+04, 5.954282e+04, 5.958636e+04,
#        5.977671e+04, 5.977085e+04, 5.968965e+04, 5.956622e+04,
#        5.951952e+04, 5.968479e+04, 5.972652e+04, 5.966311e+04,
#        5.956070e+04, 5.952714e+04, 5.948417e+04, 5.946909e+04,
#        5.956991e+04, 5.968650e+04, 6.008425e+04, 6.012120e+04,
#        6.010129e+04, 5.991432e+04, 5.982883e+04, 5.987318e+04,
#        5.982815e+04, 5.996024e+04, 6.000925e+04, 5.982497e+04,
#        5.972145e+04, 5.979638e+04, 5.980658e+04, 5.990535e+04,
#        5.967948e+04, 5.962238e+04, 5.953758e+04, 5.942975e+04,
#        5.932523e+04, 5.935617e+04, 5.947384e+04, 5.932125e+04,
#        5.924521e+04, 5.925316e+04, 5.927653e+04, 5.933074e+04,
#        5.911164e+04, 5.896163e+04, 5.915167e+04, 5.917733e+04,
#        5.917331e+04, 5.916681e+04, 5.922835e+04, 5.921739e+04,
#        5.910818e+04, 5.935927e+04, 6.003967e+04, 5.999477e+04,
#        6.054965e+04, 6.057637e+04, 6.054743e+04, 6.060994e+04,
#        6.054191e+04, 6.064060e+04, 6.066036e+04, 6.068831e+04,
#        6.061847e+04, 6.049466e+04, 6.043243e+04, 6.048687e+04,
#        6.053615e+04, 6.081968e+04, 6.080881e+04, 6.073450e+04,
#        6.076409e+04, 6.066982e+04, 6.060533e+04, 6.058986e+04,
#        6.062633e+04, 6.059621e+04, 6.059442e+04, 6.054847e+04,
#        6.054876e+04, 6.054321e+04, 6.058327e+04, 6.044460e+04,
#        6.044416e+04, 6.045589e+04, 6.034056e+04, 6.032566e+04,
#        6.042744e+04, 6.042762e+04, 6.037342e+04, 6.032860e+04,
#        6.023034e+04, 6.017998e+04, 6.032440e+04, 6.025916e+04,
#        6.026883e+04, 6.023621e+04, 6.023898e+04, 6.030451e+04,
#        6.021570e+04, 6.011183e+04, 5.997520e+04, 5.992322e+04,
#        5.989140e+04, 5.970662e+04, 5.970898e+04, 5.972721e+04,
#        5.964402e+04, 5.965764e+04, 5.964738e+04, 5.955299e+04,
#        5.959571e+04, 5.960931e+04, 5.969136e+04, 5.963753e+04,
#        5.978835e+04, 5.969116e+04, 5.968372e+04, 5.962556e+04,
#        5.988798e+04, 6.002737e+04, 2.000000e+00])

# %%
next_time_marker=datetime.now()+timedelta(minutes=5)

new_time=False
if (datetime.now()>=next_time_marker):
    new_time=True
    print('hit new time')

# %%
### !!!!!!!!!!!!!!!!
#when it goes into buy it currenlty just doess 5 minutes but the prediction line needs to update every 5 + 10 + 15, etc.
#so predict_line=slope*(len(window)+1)+intercept ... predict_line=slope*(len(window)+2)+intercept
#okay, did it for live but need to update for historical - and should check to make sure it works, gives updates of
#new value to hit every five minutes

#oh and a switch true or false in case need to run without resetting variablesf
#catch error if authentification doesn't work?
#things to experiment with down the line
#will adding an r squared guard help? or help give an adjusted range?
#predict against a giant all - perhaps take out of the line up for awhile?
#slope modifes risk?

#this one updates linear all the time even during a buy phase

hold=0
total=10000
fee=0
fee_rate=.005
buy_perc=.997
sell_perc=1.018
buy_hit_number=0
sell_hit_number=0




is_live=True

if(is_live):
    c = cbpro.PublicClient()
    #  right now I manually get the window but I want to add that as a function 
    historical = pd.DataFrame(c.get_product_historic_rates(product_id='BTC-USDT', granularity=300))
    historical.columns= ["Date","Open","High","Low","Close","Volume"]
    historical['Date'] = pd.to_datetime(historical['Date'], unit='s')
    historical.set_index('Date', inplace=True)
    historical.sort_values(by='Date', ascending=True, inplace=True)
    
    window=historical.iloc[300-144:].High.to_numpy()
    
    #appends the window every 5 minutes
    next_time_marker=datetime.now()+timedelta(minutes=5)

    
    x = np.arange(0,len(window))
    y = window
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    predict_line=slope*(len(window)+1)+intercept  
    regress_values=x*slope+intercept
    
    plt.plot(x,y)
    plt.plot(x,regress_values,'-r')
    plt.plot(x,regress_values*.99,'-g')
    plt.plot(x,regress_values*1.01,'-y')
    plt.show()
    
    while True:#currently have no exit
        
        
        auth_client = cbpro.AuthenticatedClient(public,secret,passphrase)
        time.sleep(1)
        ticker=float(ticker_update('BTC').json()['price'])  
        

        if (ticker<predict_line*buy_perc and hold==0):
                buy_hit_number=ticker
                hold=1

        if (hold==1 and ticker>buy_hit_number):
            buy_price=ticker
            print('')
            print(f'buy price: {buy_price}')
            print(f'transaction fee${total*fee_rate}')
            print(f'at: {datetime.now()}')
            print('')
            fee=fee+(total*fee_rate)
            count=1
            predict_line=slope*(len(window)+count)+intercept
            hold=2

        else:
            buy_hit_number=ticker

        if (hold==2 and (ticker>predict_line*sell_perc or ticker>buy_price*1.2)):
            sell_hit_number=ticker
            hold=3


        if (hold==3 and ticker<sell_hit_number):
            sell_price=ticker
            print('')
            print(f'sell price: {sell_price}')
            print(f'transaction fee${total*fee_rate}')
            print(f'at: {datetime.now()}')
            print('')
            hold=0

            print('--------------------')
            print(f'You made: ${(sell_price/buy_price*total)-total}')
            total=sell_price/buy_price*total
            fee=fee+(total*fee_rate)
            
            #gets new slope since it hasn't been doing it during the buy sell period
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            predict_line=slope*(len(window)+1)+intercept
            print(f'new slope: {slope}')
            count=0
            
        else:
            sell_hit_number=ticker

        #update window and regression line every five minutes or whatever is set above
        if (datetime.now()>=next_time_marker):
            print(f'time update: {datetime.now()}')
            print(f'ticker update: {ticker}')
            
            #resets new time
            next_time_marker=datetime.now()+timedelta(minutes=5)
        
            window = np.delete(window, (0), axis=0)
            window = np.append(window, ticker)
            y = window
             
             #@@@@@@@!!!!@!!@$!$$!changed thiis one to greater than equal to 0 to test if updating regularly during buy helps   
            
            if (hold>=0):#doesn't update predict line during buy and sell mode       
                slope, intercept, r_value, p_value, std_err = linregress(x, y)
                predict_line=slope*(len(window)+1)+intercept
                print(f'new slope: {slope}')
            else:
                predict_line=slope*(len(window)+count)+intercept
                count=count+1


#------------------------------------------------------------------------------    
  

if(is_live==False):
                      
      
    window=pd.read_csv("BTC_2021_11_12_coinbase.csv").iloc[0:144].High.to_numpy()#or however long
    df=pd.read_csv("BTC_2021_11_12_coinbase.csv").iloc[len(window):288]

    x = np.arange(0,len(window))
    y = window
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    predict_line=slope*(len(window)+1)+intercept                    
    
    for i, j in df.iterrows():



        if (j.Close<predict_line*buy_perc and hold==0):
            buy_hit_number=j.Close
            hold=1

        if (hold==1 and j.Close>buy_hit_number):
            buy_price=j.Close
            print('')
            print(f'buy price: {buy_price}')
            print(f'transaction fee${total*fee_rate}')
            print(f'at: {i}')
            print('')
            fee=fee+(total*fee_rate)
            hold=2

            regress_values=x*slope+intercept
            plt.plot(df.Close)
            plt.plot(x,regress_values,'-r')
            plt.plot(x,regress_values*.99,'-g')
            plt.plot(x,regress_values*1.01,'-y')


        else:
            buy_hit_number=j.Close

        if (hold==2 and (j.Close>predict_line*sell_perc or j.Close>buy_price*1.02)):
            sell_hit_number=j.Close
            hold=3


        if (hold==3 and j.Close<sell_hit_number):
            sell_price=j.Close
            print('')
            print(f'sell price: {sell_price}')
            print(f'transaction fee${total*fee_rate}')
            print(f'at: {i}')
            print('')
            hold=0

            print('--------------------')
            print(f'You made: ${(sell_price/buy_price*total)-total}')
            total=sell_price/buy_price*total
            fee=fee+(total*fee_rate)
            
            #gets new slope since it hasn't been doing it during the buy sell period
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            predict_line=slope*(len(window)+1)+intercept
            print(f'new slope: {slope}')
            
        else:
            sell_hit_number=j.Close

        #update window and regression line
        window = np.delete(window, (0), axis=0)
        window = np.append(window, j.Close)
        y = windowzz
        if (hold==0):#doesn't update predict line during buy and sell mode
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            predict_line=slope*len(window)+intercept

    #if it ends without a sale
    if (hold==10):#change this to 0 if want to have it sell at end of df
        sell_price=j.Close
        sell_price=j.Close
        print('')
        print(f'sell price: {sell_price}')
        print(f'transaction fee${total*fee_rate}')
        print(f'at: {i}')
        print('')
        hold=0

        print('--------------------')
        print(f'You made: ${(sell_price/buy_price*total)-total}')
        total=sell_price/buy_price*total
        fee=fee+(total*fee_rate)
        print('ditch sell')
    


    print('--------------------')
    print('--------------------')
    print(f'final total is ${total}')
    print(f'final fee is ${fee}')
    print(f'You made ${total-fee}')
    print('--------------------')
    print('--------------------')
# Out:
# buy price: 46279.47
# transaction fee$50.0
# at: 2021-12-20 01:00:15.965293
#
# time update: 2021-12-20 01:05:09.956248
# ticker update: 46122.93
# new slope: -4.136449501647781
# time update: 2021-12-20 01:10:10.117880
# ticker update: 46041.73
# new slope: -4.320376577445547
# time update: 2021-12-20 01:15:11.079730
# ticker update: 45951.52
# new slope: -4.525748512981275
# time update: 2021-12-20 01:20:11.203727
# ticker update: 46078.1
# new slope: -4.683520979020984
# time update: 2021-12-20 01:25:11.392318
# ticker update: 45996.31
# new slope: -4.853071718511379
# time update: 2021-12-20 01:30:11.984745
# ticker update: 46052.89
# new slope: -5.010624608150475
# time update: 2021-12-20 01:35:12.015000
# ticker update: 46043.42
# new slope: -5.159497608713132
# time update: 2021-12-20 01:40:12.214286
# ticker update: 46035.03
# new slope: -5.307501004742391
# time update: 2021-12-20 01:45:12.267073
# ticker update: 45955.84
# new slope: -5.4745065710152
# time update: 2021-12-20 01:50:12.794657
# ticker update: 45992.92
# new slope: -5.639005807410988
# time update: 2021-12-20 01:55:13.302249
# ticker update: 45997.58
# new slope: -5.808351398601405
# time update: 2021-12-20 02:00:14.830081
# ticker update: 45837.17
# new slope: -6.043292138895591
# time update: 2021-12-20 02:05:15.786512
# ticker update: 45964.59
# new slope: -6.20424851298128
# time update: 2021-12-20 02:10:17.017895
# ticker update: 46019.32
# new slope: -6.275021240254007
# time update: 2021-12-20 02:15:17.279760
# ticker update: 46100.74
# new slope: -6.286675126597549
# time update: 2021-12-20 02:20:18.633953
# ticker update: 46069.14
# new slope: -6.317422594646739
# time update: 2021-12-20 02:25:19.094275
# ticker update: 45990.9
# new slope: -6.3806441202475765
# time update: 2021-12-20 02:30:20.343974
# ticker update: 45941.95
# new slope: -6.445320291777194
# time update: 2021-12-20 02:35:21.153532
# ticker update: 45985.93
# new slope: -6.505515432843029
# time update: 2021-12-20 02:40:21.230952
# ticker update: 45952.67
# new slope: -6.5744758058034005
# time update: 2021-12-20 02:45:21.976244
# ticker update: 45949.62
# new slope: -6.5905106904589745
# time update: 2021-12-20 02:50:23.015136
# ticker update: 45979.54
# new slope: -6.580600514428107
# time update: 2021-12-20 02:55:23.822681
# ticker update: 45915.22
# new slope: -6.56952250622941
# time update: 2021-12-20 03:00:25.006302
# ticker update: 45874.71
# new slope: -6.495606241459695
# time update: 2021-12-20 03:05:25.968548
# ticker update: 45863.9
# new slope: -6.458855497950334
# time update: 2021-12-20 03:10:27.032815
# ticker update: 46101.01
# new slope: -6.3938661884093015
# time update: 2021-12-20 03:15:28.171913
# ticker update: 46006.88
# new slope: -6.382950687243799
# time update: 2021-12-20 03:20:28.242637
# ticker update: 46057.24
# new slope: -6.357893517402143
# time update: 2021-12-20 03:25:28.744296
# ticker update: 46051.97
# new slope: -6.330212945100881
# time update: 2021-12-20 03:30:29.539442
# ticker update: 46112.87
# new slope: -6.307886564584847
# time update: 2021-12-20 03:35:30.609239
# ticker update: 46075.09
# new slope: -6.296650570693682
# time update: 2021-12-20 03:40:30.766513
# ticker update: 46058.41
# new slope: -6.320577666586294
# time update: 2021-12-20 03:45:31.246867
# ticker update: 46053.85
# new slope: -6.336980166385345
# time update: 2021-12-20 03:50:31.493633
# ticker update: 46049.5
# new slope: -6.3640089221123795
# time update: 2021-12-20 03:55:32.130259
# ticker update: 46091.25
# new slope: -6.3895211799694644
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     169             conn = connection.create_connection(
# --> 170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     181             raise NewConnectionError(
# --> 182                 self, "Failed to establish a new connection: %s" % e
#     183             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fc82c700390>: Failed to establish a new connection: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='api.exchange.coinbase.com', port=443): Max retries exceeded with url: /products/BTC-USD/ticker (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc82c700390>: Failed to establish a new connection: [Errno 60] Operation timed out',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-15-16911750881e> in <module>
#      60         auth_client = cbpro.AuthenticatedClient(public,secret,passphrase)
#      61         time.sleep(1)
# ---> 62         ticker=float(ticker_update('BTC').json()['price'])
#      63
#      64
#
# <ipython-input-9-b4acdf15a6fa> in ticker_update(my_ticker)
#       7     headers = {"Accept": "application/json"}
#       8
# ----> 9     response = requests.request("GET", url, headers=headers)
#      10
#      11     return response
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.exchange.coinbase.com', port=443): Max retries exceeded with url: /products/BTC-USD/ticker (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc82c700390>: Failed to establish a new connection: [Errno 60] Operation timed out',))

# %%
ticker=float(ticker_update('BTC').json()['price'])
ticker
# Out:
# 46546.42

# %%
regress_values=x*slope+intercept
plt.plot(x,window)
plt.plot(x,regress_values,'-r')
plt.plot(x,regress_values*.99,'-g')
plt.plot(x,regress_values*1.01,'-y')

# %%
regress_values=x*slope+intercept
plt.plot(df.Close)
plt.plot(x,regress_values,'-r')
plt.plot(x,regress_values*.99,'-g')
plt.plot(x,regress_values*1.01,'-y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a1716c041b53> in <module>
#       1 regress_values=x*slope+intercept
# ----> 2 plt.plot(df.Close)
#       3 plt.plot(x,regress_values,'-r')
#       4 plt.plot(x,regress_values*.99,'-g')
#       5 plt.plot(x,regress_values*1.01,'-y')
#
# NameError: name 'df' is not defined

# %%
df=historical
#can upload this: 'dec_2_spike_kmd.csv'
#test bot
hold=0#default
buy_price=0 #default
old_price=1.2 #when to buy
sell_price=0 #default
new_high=0 #default
original_spend=5000
spend=original_spend #how much to invest
for i, j in df.iterrows():

    if (j.Close<regress_values*.98 and hold==0):
        buy_price=j.price
        new_high=buy_price
        print(f'num={i}')
        print(j.timestamp)
        hold=1
    if (j.price>new_high):
        new_high=j.price
    if (hold==1 and j.price<=new_high*.96 and j.price>buy_price*1.1):#makes sure there isn't a loss for the sell
        sell_price=j.price
        print(f'num={i}')
        print(j.timestamp)
        hold=2
        
    if (hold==2 and j.price>=new_high*1):
        spend=spend+((sell_price/buy_price)*(spend*.98)-spend)
        buy_price=j.price
        new_high=buy_price
        #I will rebuy here with total .... {(sell_price/buy_price)*(spend*.98)-spend}
        hold=1 
        print(f'num={i}')
        print(j.timestamp)
            
print (buy_price)
print (sell_price)
print (f'You made ${(sell_price/buy_price)*(spend*.98)+spend-original_spend*2}')

#maybe not reinvest all option so if It hits 500 keeps 250 for a guaranteed profit?
#and when it hits check to see if there recent twitter post counts?
#time limit or too low?
#perhaps check to see trend and if it jumps by a percentage even if it isn't a new high? 10%?  track new low after new high and if suddenly it jumps up even if it isn't at new high buy again?
#check predictions? in the api
# Out:
# num=20614
# 2021-12-02T15:56:40.809Z
# num=68625
# 2021-12-02T17:58:18.47Z
# num=76033
# 2021-12-02T18:01:44.625Z
# 1.4888
# 1.4287
# You made $1317.4185090772808

# %%
df=pd.read_csv('dec_6_spike_kmd.csv')
#test bot
hold=0#default
buy_price=0 #default
old_price=.86 #when to buy
sell_price=0 #default
new_high=0 #default
original_spend=5000
spend=original_spend #how much to invest
for i, j in df.iterrows():

    if (j.price>old_price and hold==0):
        buy_price=j.price
        new_high=buy_price
        print(f'num={i}')
        print(j.timestamp)
        hold=1
    if (j.price>new_high):
        new_high=j.price
    if (hold==1 and j.price<=new_high*.96 and j.price>buy_price*1.1):#makes sure there isn't a loss for the sell
        sell_price=j.price
        print(f'num={i}')
        print(j.timestamp)
        hold=2
        
    if (hold==2 and j.price>=new_high*1):
        spend=spend+((sell_price/buy_price)*(spend*.98)-spend)
        buy_price=j.price
        new_high=buy_price
        #I will rebuy here with total .... {(sell_price/buy_price)*(spend*.98)-spend}
        hold=1 
        print(f'num={i}')
        print(j.timestamp)
            
print (buy_price)
print (sell_price)
print (f'You made ${(sell_price/buy_price)*(spend*.98)+spend-original_spend*2}')
# Out:
# num=5500
# 2021-12-06T16:03:52.921Z
# num=8457
# 2021-12-06T16:07:45.348Z
# 0.8603
# 0.9531
# You made $428.5598047192834

# %%
################## MY MILLIONAIRE BOT #######################

# %%
import cbpro

# %%
#get available products
pc=cbpro.PublicClient()
results=pc.get_products()
for row in results:
    print(row['id'])
# Out:
# CHZ-USD
# PAX-USD
# FIL-USD
# REN-BTC
# PERP-USD
# ETH-USDC
# NKN-USD
# BAT-BTC
# CRV-BTC
# CTSI-USD
# CVC-USDC
# FX-USD
# STORJ-BTC
# ZEC-USD
# ZRX-USD
# DASH-BTC
# AXS-BTC
# MASK-USDT
# UST-EUR
# MASK-USD
# LCX-USDT
# VGX-USD
# MIR-BTC
# ADA-EUR
# DOGE-USDT
# CVC-USD
# NU-USD
# RAD-USD
# BAND-EUR
# WLUNA-GBP
# ENJ-BTC
# LTC-USD
# SNX-EUR
# NU-GBP
# KRL-USDT
# NMR-EUR
# OMG-EUR
# TRAC-USD
# NMR-USD
# ZRX-EUR
# REN-USD
# POLY-USD
# GTC-USD
# YFI-BTC
# ALCX-USDT
# ETC-BTC
# MCO2-USDT
# RLY-GBP
# LCX-EUR
# GRT-USD
# UST-USDT
# ETH-USDT
# CRV-EUR
# UMA-EUR
# XLM-USD
# BCH-BTC
# CLV-GBP
# ALCX-EUR
# SNX-GBP
# NMR-BTC
# EOS-EUR
# XYO-USDT
# IOTX-USDT
# MANA-ETH
# UMA-BTC
# TRIBE-USD
# DOGE-USD
# RAD-GBP
# KRL-EUR
# OMG-GBP
# TRU-USDT
# AXS-USD
# ETH-BTC
# DASH-USD
# BTRST-USDT
# FIL-EUR
# POWR-USDT
# RGT-USD
# FET-USD
# MANA-USDC
# LOOM-USDC
# ARPA-EUR
# FORTH-EUR
# STORJ-USD
# 1INCH-BTC
# BAT-EUR
# MLN-USD
# MIR-GBP
# ASM-USD
# UNI-USD
# BAT-USDC
# CRO-EUR
# DOGE-GBP
# WCFG-GBP
# REP-USD
# BICO-USD
# FOX-USDT
# BNT-USD
# SOL-GBP
# FARM-USDT
# MANA-USD
# KNC-USD
# ZEN-BTC
# ETC-USD
# AXS-EUR
# ENS-USD
# ICP-BTC
# DDX-USDT
# MATIC-USD
# IDEX-USD
# BTC-USDC
# UNI-GBP
# ARPA-USD
# CGLD-BTC
# CHZ-EUR
# RAD-EUR
# CGLD-GBP
# RLC-USD
# DOT-USD
# ASM-USDT
# USDT-USD
# POLY-USDT
# NU-EUR
# MIR-USD
# ALCX-USD
# ADA-GBP
# AAVE-GBP
# NKN-EUR
# SOL-USD
# DNT-USD
# SUSHI-GBP
# TRAC-EUR
# SUSHI-USD
# ENJ-USD
# BTRST-BTC
# ORN-BTC
# COMP-BTC
# MASK-EUR
# BCH-EUR
# LTC-GBP
# AVAX-USDT
# CLV-EUR
# DOT-GBP
# USDT-USDC
# ANKR-USD
# ALGO-GBP
# WLUNA-USDT
# MKR-BTC
# FORTH-GBP
# TRU-BTC
# LINK-EUR
# USDC-EUR
# GYEN-USD
# SHIB-EUR
# BADGER-EUR
# DOT-EUR
# TRAC-USDT
# LPT-USD
# NU-BTC
# ANKR-BTC
# SKL-BTC
# 1INCH-USD
# UMA-USD
# BNT-BTC
# ZEC-BTC
# ANKR-GBP
# SUSHI-EUR
# AUCTION-USD
# IOTX-USD
# EOS-BTC
# CRV-GBP
# ZEC-USDC
# REQ-BTC
# OMG-USD
# AVAX-EUR
# FARM-USD
# LTC-BTC
# XYO-BTC
# DOT-USDT
# POLS-USD
# COVAL-USDT
# AGLD-USD
# BCH-GBP
# SPELL-USDT
# AVAX-USD
# TRU-USD
# BTC-GBP
# USDT-GBP
# ADA-ETH
# SOL-ETH
# ENS-USDT
# XLM-BTC
# WBTC-BTC
# ANKR-EUR
# LINK-BTC
# IOTX-BTC
# ATOM-BTC
# SHIB-USD
# FIL-GBP
# BTC-UST
# ALGO-BTC
# AXS-USDT
# BADGER-USDT
# WCFG-EUR
# POWR-EUR
# BNT-EUR
# SHIB-GBP
# DOGE-BTC
# CGLD-USD
# LCX-USD
# AAVE-USD
# WBTC-USD
# CHZ-GBP
# NKN-GBP
# FORTH-BTC
# RLC-BTC
# PLA-USD
# ZEN-USDT
# BAT-USD
# MANA-BTC
# OXT-USD
# POLS-USDT
# GALA-USDT
# ETH-DAI
# UNI-BTC
# LRC-USD
# DDX-USD
# QNT-USD
# PERP-EUR
# ICP-GBP
# KNC-BTC
# FIL-BTC
# DDX-EUR
# UMA-GBP
# ICP-USDT
# LTC-EUR
# ALGO-USD
# NKN-BTC
# SUKU-USDT
# ETH-EUR
# ORN-USDT
# SKL-GBP
# POWR-USD
# SHIB-USDT
# YFII-USD
# BADGER-USD
# BTRST-USD
# XTZ-EUR
# GRT-GBP
# BTC-USDT
# PERP-USDT
# LINK-ETH
# CGLD-EUR
# ATOM-GBP
# ETC-EUR
# GNT-USDC
# ATOM-EUR
# WCFG-USDT
# IDEX-USDT
# KEEP-USD
# MKR-USD
# QUICK-USD
# BTRST-EUR
# CLV-USDT
# BICO-EUR
# COTI-USD
# MATIC-BTC
# EOS-USD
# RAD-USDT
# XTZ-USD
# BTC-USD
# AGLD-USDT
# ZEN-USD
# AUCTION-EUR
# BTC-EUR
# MASK-GBP
# DOGE-EUR
# XYO-EUR
# BAT-ETH
# DAI-USDC
# SOL-BTC
# UNI-EUR
# MUSD-USD
# REQ-EUR
# COMP-USD
# WLUNA-BTC
# LINK-GBP
# SKL-EUR
# REP-BTC
# AMP-USD
# SUSHI-BTC
# SOL-USDT
# GALA-USD
# AAVE-BTC
# AVAX-BTC
# USDT-EUR
# SUSHI-ETH
# ICP-USD
# 1INCH-GBP
# CTSI-BTC
# ICP-EUR
# LRC-BTC
# GALA-EUR
# SUKU-EUR
# COVAL-USD
# WLUNA-USD
# ACH-USD
# CRO-USDT
# WCFG-BTC
# FET-USDT
# CRO-USD
# TRU-EUR
# AAVE-EUR
# IOTX-EUR
# DAI-USD
# RLY-USDT
# RARI-USD
# ADA-BTC
# XTZ-BTC
# XYO-USD
# MCO2-USD
# 1INCH-EUR
# FORTH-USD
# RAD-BTC
# VGX-USDT
# XTZ-GBP
# ADA-USDC
# ATOM-USD
# ORN-USD
# ETH-USD
# TRB-BTC
# ADA-USD
# MATIC-EUR
# ETC-GBP
# BAL-BTC
# ARPA-USDT
# ZRX-BTC
# SUPER-USDT
# RLY-EUR
# SUKU-USD
# REQ-GBP
# ENS-EUR
# YFI-USD
# NMR-GBP
# SNX-USD
# CRV-USD
# SKL-USD
# BTRST-GBP
# VGX-EUR
# OMG-BTC
# ETH-GBP
# FOX-USD
# REQ-USDT
# USDC-GBP
# LOOM-USD
# ALGO-EUR
# BAL-USD
# MATIC-GBP
# OGN-USD
# BCH-USD
# AUCTION-USDT
# SUPER-USD
# DNT-USDC
# XLM-EUR
# REQ-USD
# SNX-BTC
# PAX-USDT
# BAND-USD
# RLY-USD
# BICO-USDT
# JASMY-USD
# LINK-USD
# KRL-USD
# OGN-BTC
# GRT-BTC
# UST-USD
# SPELL-USD
# BNT-GBP
# RAI-USD
# WLUNA-EUR
# DOT-BTC
# CHZ-USDT
# MANA-EUR
# SOL-EUR
# BAND-BTC
# MIR-EUR
# TRB-USD
# CLV-USD
# WCFG-USD
# BAND-GBP
# BOND-USD
# GRT-EUR

# %%
#get my coinbase psscodes
myps=open('../phrase.txt','r').read().splitlines()
public = myps[2].split(':')[1]
passphrase = myps[0].split(':')[1]
secret = myps[1].split(':')[1]

# %%
#create my client
auth_client = cbpro.AuthenticatedClient(public,secret,passphrase)

# %%
#verify my client
auth_client.get_accounts()
# Out:
# [{'id': '6816884e-323c-4bbe-a17d-19f983531c08',
#   'currency': '1INCH',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'a6c04dbc-7d9d-47ad-9e00-2496e9c83d55',
#   'currency': 'AAVE',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'fd3a3da9-f798-4d37-9a24-95b0e85765a5',
#   'currency': 'ACH',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '12e1a26d-c4b6-4de5-a58e-ca617e550262',
#   'currency': 'ADA',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '980f54ed-c254-4359-84d1-769fc70a7588',
#   'currency': 'AGLD',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '46d46d69-f395-4255-a399-05cbdf4b6815',
#   'currency': 'ALCX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '52953b48-e57c-49e6-8bd8-a96a12f9af45',
#   'currency': 'ALGO',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'dafb84a9-d535-4353-b022-b9e1396807c1',
#   'currency': 'AMP',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '02df1d0e-5d14-4ebc-8c55-5f275e34c9c8',
#   'currency': 'ANKR',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '845b268c-235a-4331-94cb-3f1db3369260',
#   'currency': 'API3',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '80d4c443-6856-44db-8bae-26ff206aa15f',
#   'currency': 'ARPA',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'f0a27d37-2445-4e15-986c-6521ddc7f979',
#   'currency': 'ASM',
#   'balance': '71.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '71',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '312614d0-ba37-4ec1-a3a9-8e6b4798fefe',
#   'currency': 'ATOM',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '943f3bef-5c27-4945-8f6d-2c19611b7ce8',
#   'currency': 'AUCTION',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '6ce240ad-06e9-4f4f-99cc-adf4c2ab61e3',
#   'currency': 'AVAX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '9996b8fa-93c3-4fe2-8477-07a62c4e0517',
#   'currency': 'AXS',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'cae58b50-1209-4155-b021-1c86b82c9721',
#   'currency': 'BADGER',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'ab1f1fa5-8dba-41c0-ae48-ec39e6359d2c',
#   'currency': 'BAL',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '635fc960-213b-4722-af5c-b692ec0ef2fb',
#   'currency': 'BAND',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '46562484-04d2-4f94-a768-181036d234ba',
#   'currency': 'BAT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'b342a92d-badb-4776-a474-c6cfad0a960d',
#   'currency': 'BCH',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '5e2a6ee2-d465-428b-9e22-adde03c9384d',
#   'currency': 'BICO',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '455ba816-2b90-41f7-81ce-b6eb7a33b1e6',
#   'currency': 'BLZ',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'ee59e1a9-719a-44ea-84c1-86f54ce93330',
#   'currency': 'BNT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '65c7519b-cc15-4cdc-858e-7cb03f72b10f',
#   'currency': 'BOND',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '4fd2b68c-706c-4910-9359-422d807d3ae8',
#   'currency': 'BTC',
#   'balance': '0.0082609800000000',
#   'hold': '0.0000000000000000',
#   'available': '0.00826098',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'f5e44e15-b207-4121-b124-1d2ecba3b22a',
#   'currency': 'BTRST',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '5f37d292-5542-4f3b-919b-e72a920aa84b',
#   'currency': 'CGLD',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'f8f0e8d6-f2ad-44f7-a088-cda6be1a657f',
#   'currency': 'CHZ',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'f532ba0d-b80d-410b-9532-d566a9850c00',
#   'currency': 'CLV',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'a9fa0644-2dc1-4ff3-83bc-0229715ed15d',
#   'currency': 'COMP',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '96add7a0-ffdf-4dab-a7fb-542b7dad8280',
#   'currency': 'COTI',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'e8766570-aa0d-4535-af8b-860ed4f1e7d4',
#   'currency': 'COVAL',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '25f1680d-bbe4-4c7c-9559-fa14b3613968',
#   'currency': 'CRO',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '44902722-767f-4e09-9a31-f8ed56b50130',
#   'currency': 'CRV',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '199b43f3-f304-4983-917d-29220fa8a848',
#   'currency': 'CTSI',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '8be6c05d-085f-4ab1-8128-6d23e75df9ae',
#   'currency': 'CVC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '8cdbfe32-013e-4fc8-bd9d-a5758dd00a64',
#   'currency': 'DAI',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '7d910d93-efe8-41c8-863f-75bbd94edf9f',
#   'currency': 'DASH',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '3dc569b3-2ff4-4154-9126-2d2f37dc667c',
#   'currency': 'DDX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '0b00d848-5477-400e-b945-3d02b56dc327',
#   'currency': 'DNT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '7bf2c4a7-acaf-474d-98d2-61586c3aed1a',
#   'currency': 'DOGE',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '9e7b82b2-3c8d-4708-990c-9a2b5a0f6a13',
#   'currency': 'DOT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '1dd7189a-8499-40ed-b8c5-2172ad2589d3',
#   'currency': 'ENJ',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '4ddf62b5-678c-41f3-b395-3692ad637ee0',
#   'currency': 'ENS',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '053ec29a-7d03-49e4-9f35-6cbb64b54661',
#   'currency': 'EOS',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '1716ef5a-a1b0-4c90-8322-bdc5061a5942',
#   'currency': 'ETC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'aba2a067-8b69-44cb-b541-1b97824d419f',
#   'currency': 'ETH',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '3232431e-fdeb-4c77-ac8e-528f63f611b7',
#   'currency': 'FARM',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '3d1c048c-ae25-4b68-b1cf-378af7cc76ea',
#   'currency': 'FET',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'fd065a65-5130-4fb7-b3c3-0b78e122e342',
#   'currency': 'FIL',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '7f7df9b2-ca4b-4366-81fc-1f14747a9a91',
#   'currency': 'FORTH',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '60ebce32-b507-4af4-898b-2a34a001a91a',
#   'currency': 'FOX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '35d62433-2c6b-4611-9d77-10ee9934dae6',
#   'currency': 'FX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '5ad8441c-9b1a-4202-ad5a-2088c48abcd0',
#   'currency': 'GALA',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'd6c62cc9-afee-44c4-b750-1f760f433246',
#   'currency': 'GNT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '66683cc6-e705-4570-9b1b-d775b4498000',
#   'currency': 'GODS',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'cb5012d5-67fc-411c-9b05-35cb42318efa',
#   'currency': 'GRT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'cbb11ea2-71b8-491a-8789-de8b1cf63b6d',
#   'currency': 'GTC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '8e9219b0-548c-47d4-a2da-f98ec5fa69dc',
#   'currency': 'GYEN',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'f348a339-2c68-4626-b43b-a2ca50b46267',
#   'currency': 'ICP',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '21490340-1dbc-4500-8288-24146c9cf49b',
#   'currency': 'IDEX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '29abf1f6-52fc-4517-92d7-1bf5f7591006',
#   'currency': 'IMX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '91430972-f546-4986-8fac-f88ac5c037ff',
#   'currency': 'IOTX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '8812bc8e-a7e9-4203-acca-3804b632c88a',
#   'currency': 'JASMY',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '4010162a-4948-4f90-af6b-f2ad8752fd71',
#   'currency': 'KEEP',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '1cd340bf-047b-4d1c-b4f1-c2050c0ae57a',
#   'currency': 'KNC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '655c8f79-30a5-48b5-81d5-6e0a41726a6b',
#   'currency': 'KRL',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '8212323b-54ca-4b91-992c-fcdcecdf81ba',
#   'currency': 'LCX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '7a8871d0-f743-40c9-a226-8e8a50c7b80e',
#   'currency': 'LINK',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'a968d160-6cf9-4730-9d77-273a2007f2c9',
#   'currency': 'LOOM',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'd96c2894-9ac2-42fb-ad65-91251947f6c0',
#   'currency': 'LPT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'd477e185-6956-419c-b893-dbe3065bdc7c',
#   'currency': 'LRC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '1b034a9c-1c74-437a-9801-0a5f9fcdac72',
#   'currency': 'LTC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'd06127de-ad19-49f3-9051-9c272dad1f0c',
#   'currency': 'MANA',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'f8765463-bde3-4c7c-8c92-4484ba10d156',
#   'currency': 'MASK',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '78658b6c-8617-4848-8deb-5600a215ab64',
#   'currency': 'MATIC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '6a914074-bc95-4e97-9955-9763ebf5445b',
#   'currency': 'MCO2',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '31607548-2ebe-4bfd-ac9e-4a276ee23b91',
#   'currency': 'MDT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '26e08302-008a-4ff2-a74d-8507e89dba4e',
#   'currency': 'MIR',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'bf4572f8-04e2-4d16-a312-eeb40292a613',
#   'currency': 'MKR',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '19869f70-c7b6-4d62-b204-3b3d57559258',
#   'currency': 'MLN',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '2ce25958-2d55-4d67-9e33-2c33dcf527f9',
#   'currency': 'MUSD',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '7f823e60-aef8-4745-bfb3-4c7e9fb4d34c',
#   'currency': 'NKN',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '71055f68-f99d-428f-af0a-a40810c010b2',
#   'currency': 'NMR',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'dbb6fdeb-3753-4569-a0f8-5582f487f678',
#   'currency': 'NU',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '2e1af510-8907-4dfb-95bd-d7a2eceae370',
#   'currency': 'OGN',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '321c2ac8-d7b1-4a9a-9b6f-f29d313e1516',
#   'currency': 'OMG',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '667dcc99-2671-4dfb-be10-5dc386d1384c',
#   'currency': 'ORN',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '360e30e5-6d6b-41ef-9334-10d107751eb1',
#   'currency': 'OXT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '3f7739ba-0a83-4f51-8187-3f1711abb6ec',
#   'currency': 'PAX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '68acab74-69c6-4dae-801e-9685b7a184de',
#   'currency': 'PERP',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '597e16b3-d9f2-48c2-b361-a3ffb1765ad9',
#   'currency': 'PLA',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'd5721a83-7932-4d3c-abfc-00ab85a51620',
#   'currency': 'POLS',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'ff21bdd0-12cc-4dfd-b48f-4403c25f3835',
#   'currency': 'POLY',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'af6e23b3-b5cc-4200-a058-38dbb3931cdb',
#   'currency': 'POWR',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '6ff83bdd-086d-4781-914f-284bdb2c1a51',
#   'currency': 'QNT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '7faa0bd7-863e-48a9-97c5-95e20a228d12',
#   'currency': 'QUICK',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '2df809fc-6e5c-46ae-8214-e2756a30634a',
#   'currency': 'RAD',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '5ba3e67c-649d-456e-ac4f-30e696552a09',
#   'currency': 'RAI',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'd28c9fc3-9555-4a2c-b32b-cea629086bed',
#   'currency': 'RARI',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'b7322045-0f72-4e63-8014-d49bbb1f3e53',
#   'currency': 'RBN',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '32a30027-da03-4146-af6e-d222853c5c92',
#   'currency': 'REN',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'dd394c4a-b5ec-4af0-be32-b6c50d2d5e90',
#   'currency': 'REP',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '6d9654e3-9ffd-4b36-bdc5-636f4c62c094',
#   'currency': 'REQ',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '19ad573e-a81e-43bb-a89b-a96093f31756',
#   'currency': 'RGT',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '30bdbd2d-8961-4b8e-83ec-ea9544bb5606',
#   'currency': 'RLC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '977a54a8-0496-4350-8fff-d7b8575f011f',
#   'currency': 'RLY',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '68d7a677-9bb6-42d2-91ad-157a5a4c2dda',
#   'currency': 'SHIB',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '3c2d4a22-9532-4ea9-be94-b28a7f6ec404',
#   'currency': 'SKL',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '131a9aa7-4fa7-4e8f-ab93-523b66930caf',
#   'currency': 'SNX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '3af54653-7abd-42af-8be9-1649978bacb7',
#   'currency': 'SOL',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '53f35544-3263-4919-b32d-5b22a0febba8',
#   'currency': 'SPELL',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'f2521e56-8192-40e9-ab06-fcb04112d147',
#   'currency': 'STORJ',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '51b55e2c-ff03-43b1-b24e-b78be4364973',
#   'currency': 'SUKU',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '4075dfce-4698-4f25-886d-881e471f71ba',
#   'currency': 'SUPER',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'dc8b6d2f-d624-4943-922e-b4952e27d9d9',
#   'currency': 'SUSHI',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '27e23d84-d604-45a9-9967-0cb8fcd7bf51',
#   'currency': 'TBTC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'f84784e7-0932-474d-aa06-b4106f8badfe',
#   'currency': 'TRAC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '621c898e-4ffe-477e-bf94-eb1cef893a7f',
#   'currency': 'TRB',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '481dd97b-8c81-40c8-9d0a-22fc58a1bb74',
#   'currency': 'TRIBE',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '1324eea0-b17f-4020-8be2-3a46790fa97b',
#   'currency': 'TRU',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '8b0ab497-0bef-4da5-b35f-a4e58e0bf8cc',
#   'currency': 'UMA',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'fda7f3e3-637a-49dd-b6b7-1f8f47fea7ac',
#   'currency': 'UNI',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'd2deefed-d531-4568-91fe-0692a0ea2caa',
#   'currency': 'USD',
#   'balance': '5.0077271621985000',
#   'hold': '0.0000000000000000',
#   'available': '5.0077271621985',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'd2b85127-f64a-4d3f-a4db-1c95d650c515',
#   'currency': 'USDC',
#   'balance': '201.3400000000000000',
#   'hold': '0.0000000000000000',
#   'available': '201.34',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '4b2f0581-a251-4713-8039-4d2bb5bf4306',
#   'currency': 'USDT',
#   'balance': '31.7337442288625000',
#   'hold': '0.0000000000000000',
#   'available': '31.7337442288625',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '0ade4fe9-4e1e-4c57-a47b-84748b8a06b0',
#   'currency': 'UST',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '1d48429a-76e0-4dcb-a27b-6e85535a7992',
#   'currency': 'VGX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'a513412f-1dba-4cda-915f-b124a8351c52',
#   'currency': 'WBTC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'fc2bf3a5-12c0-4cdc-91e6-7744ad37bab6',
#   'currency': 'WCFG',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '0d1ce801-c626-42f6-933f-02f5240e17ee',
#   'currency': 'WLUNA',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '52b2dfc4-a9f9-4e35-80e2-7e3b366b1ab4',
#   'currency': 'XLM',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'a3ed06d1-495e-4a90-b0ab-d87fb8702156',
#   'currency': 'XRP',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '4ccf78cc-eab0-46b6-935b-3ff908f7f7d3',
#   'currency': 'XTZ',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '46994a11-f708-4389-b81a-eb4c695ea154',
#   'currency': 'XYO',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'e29d7feb-9ba1-47eb-b636-66941b3c6386',
#   'currency': 'YFI',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '972eb26f-b3a8-4605-aebc-12a4cfce5ce1',
#   'currency': 'YFII',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': 'a08580d6-3a46-454c-9f3f-9f2a144f4070',
#   'currency': 'ZEC',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '4e01a77e-ae98-4245-a452-c4507932aa52',
#   'currency': 'ZEN',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True},
#  {'id': '4f0565d9-1ee3-4525-a66c-c293c23ee58c',
#   'currency': 'ZRX',
#   'balance': '0.0000000000000000',
#   'hold': '0.0000000000000000',
#   'available': '0',
#   'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24',
#   'trading_enabled': True}]

# %%
#function to get floor down to two decimal places
def floor_balance(value):
    return math.floor(value*100)/100

# %%
#ticker for crypto
def ticker_update(my_ticker):
    import requests
    auth_client = cbpro.AuthenticatedClient(public,secret,passphrase)
    url = "https://api.exchange.coinbase.com/products/"+my_ticker+"-USD/ticker"

    headers = {"Accept": "application/json"}

    response = requests.request("GET", url, headers=headers)

    return response

# %%
#gets available balance for sell or buy
def get_balance(curr):
    for account in accounts:
        currency=account.get('currency')
        if currency==curr:
            acc_id=account.get('id')
            print(curr)
            print(auth_client.get_account(acc_id))
    return auth_client.get_account(acc_id)['available']

# %%
#function to calculate needed value to sell, etc. for bot
def output_req(buy_price,profit_limit,sell_limit):
    purchase=10
    profit_req=buy_price*profit_limit
    high_req =100/(sell_limit*100)*profit_req
    print(f'sell price if only hits minimum: {profit_req}')
    print(f'will at least need to hit this price to auto sell {high_req}')

# %%
print(float(ticker_update('ASM').json()['price']))
print(float(ticker_update('POWR').json()['price']))
print(float(ticker_update('DDX').json()['price']))
print(float(ticker_update('SKL').json()['price']))
print(float(ticker_update('MATIC').json()['price']))
# Out:
# 0.08863
# 0.4127
# 4.39
# 0.192
# 2.0911

# %%
def get_products():
    my_products=auth_client.get_products()
    avail_products=[]

    for product in my_products:

        if (product['id'].split('-')[1]=='USDT'):
            if (product['cancel_only']==False and product['limit_only']== False and
                product['trading_disabled']== False and product['auction_mode']==False and
                product['fx_stablecoin']==False): 
                avail_products.append(product['id'].split('-')[0])#'trading_disabled''limit_only': True, 'cancel_only':
    #print (avail_products)
    #print (len(avail_products))
    return (avail_products)

# %%
get_products()#DOGE,CRO,CHZ,SPELL,GALA,KRL,TRU,REQ,RLY,WCFG
# Out:
# ['CHZ',
#  'SPELL',
#  'POLS',
#  'ICP',
#  'GALA',
#  'CRO',
#  'SHIB',
#  'KRL',
#  'SOL',
#  'BTRST',
#  'TRU',
#  'MASK',
#  'REQ',
#  'PERP',
#  'RLY',
#  'ASM',
#  'BTC',
#  'ETH',
#  'RAD',
#  'WCFG',
#  'WLUNA',
#  'XYO',
#  'AUCTION',
#  'FET',
#  'DOGE',
#  'SUKU',
#  'ORN',
#  'CLV',
#  'ENS',
#  'AXS',
#  'AVAX',
#  'BADGER',
#  'DOT',
#  'ARPA',
#  'AGLD']

# %%
def normalize(values):
    return (values - values.min())/(values.max() - values.min())
    #return (values - values.min())/(values.max() - values.min())

# %%
y=normalize(pd.DataFrame({'temp':[.1677,.1781]}))
slope, intercept, r_value, p_value, std_err = linregress([0,1],y.temp)
slope
# Out:
# 0.01040000000000002

# %%
slope
# Out:
# 0.0

# %%
float(ticker_update('BTC').json()['price'])
# Out:
# 46850.35

# %%
### add an eject button if it hits too low!
#MILLIONAIR BOT

auth_client = cbpro.AuthenticatedClient(public,secret,passphrase)
first_run=True #set this to false if cell is interuppted and I want to continue where left off
is_live=False #won't actually buy or sell


#creates a general array for y to help figure out slope of product
win_index=[]#length of the array for window #time sleep every one second then this is about 3 1/2 minutes - corresponds with time below
for i in range(0,90):
    win_index.append(i)


#the possible products    
the_products=get_products()
product_pool={}

for product in the_products:
    product_pool[product]=[]
    
#so! now I need to have it cycle through all available products and each time one matches
#the requirements, it buys and is moved into an available dictionary INCLUDING THE WINDOW
#after it sells it is moved back into circulation
#including the additional funds and the spend adjusts accordingly
        
#!!!! Temporarily overrides the entire product pool until I can find a faster way to cycle through
#the_products=['DOGE','CRO','CHZ','SPELL','GALA','TRU','REQ','RLY','WCFG']
#product_pool={'DOGE':[],'CRO':[],'CHZ':[],'SPELL':[],'GALA':[],'TRU':[],'REQ':[],'RLY':[],'WCFG':[]}    

#initializes the bots - might just be able to do one at a time unless find a way to further limit but for now 1
if (first_run==True):
    dict1 = {'crypto': '', 'hold':0,'buy_price':0 ,'new_high':0,'spend':0,'window':[]}
    #dict2 = {'crypto': '', 'hold':0,'buy_price':0 ,'new_high':0,'spend':0}
    #dict3 = {'crypto': '', 'hold':0,'buy_price':0 , 'new_high':0,'spend':0}
    #dict4 = {'crypto': '', 'hold':0,'buy_price':0 , 'new_high':0,'spend':0}
    
    currencies=[dict1] #start with just 1
    
    available_slots=len(currencies) #match the number of dictionaries possible
    
    hold=0 #0=initial, 1=hold, 2=sold (back to 0 to be put back in circulation)
    
    profit_limit=1 #sets the desired profit before selling
    sell_limit=.98 #will sell if the high price drops to this percentage (if profit limit is met too)
    #high_increase=1.0 #will buy again if price hits the current high multiplied by this
    
    #sets the spend value for each dictionary

    
print ('Bot Started!')
bot_count=0
hit_window=False
    
while True:#currently this keeps running until manually exiting
    
    
    
    
    auth_client = cbpro.AuthenticatedClient(public,secret,passphrase)
    
    #for product in the_products:
        
    price=float(ticker_update('GALA').json()['price'])
      #  product_pool[product].append(price)
        
        #bot_count=bot_count+1
        #if (bot_count==12):
         #   print(f'{product} price update at:{price} - to make sure is still live')
          #  print(len(product_pool[product]))
           # bot_count=0

        #if (len(product_pool[product])>=90):
            #print('yes')
         #   if (hit_window==False):
          #      hit_window=True
           #     print ('Let us get those buys!')
            #x = win_index
            #y = pd.DataFrame({'temp':product_pool[product]}).temp
            
            
            #!!!!!!!! THIS IS MAKING IT GO SLOW!
            #slope, intercept, r_value, p_value, std_err = linregress(x, normalize(y))
            #print(slope)
            #product_pool[product].pop(0)

    in_circulation=True

    #if not in circulation sees if a slot is available for another purchase
    #empty_slot=0 #if 0 there is no available slots for a new purchase
    #slot_count=0
    #the_slot=-1

    #for currency in currencies:

     #   if (currency['crypto']==product): #LINE 74
      #      in_circulation=True
       # if (currency['crypto']==''):
        #    the_slot=slot_count
        #slot_count=slot_count+1


    if (in_circulation==True):
        type_crypto='GALA'
        type_exchange=type_crypto+'-USDT'
        buy_price=currencies[the_slot]['buy_price']
        new_high=currencies[the_slot]['new_high']
        spend=currencies[the_slot]['spend']
        hold=currencies[the_slot]['hold']

    #check to see if it is already bought and in current circulation
    if (hold==0): ##just works with under 1 dollar for now
        #if (the_slot!=-1):
         #   currencies[the_slot]['crypto']=product #adds to the slot


        if (is_live==True):
            original_spend=float(get_balance('USDT')) #amount to spend initially on first buy
        else:
            original_spend=1000

        #currencies[the_slot]['spend']=original_spend/available_slots

        #in_circulation=True
        #available_slots=available_slots-1

        buy_price=price
        new_high=buy_price
        print('')
        print('PURCHASE ORDER:')
        print(f'date: {datetime.now()}')
        print (f'{type_crypto} :${price}')
        #print(f'buy slope: {slope}')
        #print(f'buy r squared: {r_value*r_value}')
        print('')
        print(output_req(buy_price,profit_limit,sell_limit))
        print('')

        if (is_live==True):
            the_bought=(auth_client.place_market_order(type_exchange, 'buy', funds=floor_balance(spend)))

            #checks to see if buy goes through
            if (len(the_bought)==1):
                print (the_bought)
                currencies[the_slot]['spend']=0
                currencies[the_slot]['crypto']=''
                hold=0
                print ('the buy did not go through')
            else:
                output_req(buy_price,profit_limit,sell_limit)
                currencies[the_slot]['hold']=1



    active=True
    while (active==True):
        
        price=float(ticker_update('ASM').json()['price'])

        if (price>new_high):
            new_high=price
            print(new_high)

        if (hold==1 and ((price<=new_high*sell_limit and price>buy_price*profit_limit))):#makes sure there isn't a loss for the sell
            print('')
            print('SELL ORDER:')
            print(f'date: {datetime.now()}')
            print(f'sell price: {price}')
            print(f'sell slope: {slope}')
            print(f'sell r squared: {r_value*r_value}')
            print('')

            if (is_live==True):
                print(auth_client.place_market_order(type_exchange, 'sell', size=floor_balance(float(get_balance(type_crypto)))))
            active=False


    #reset values
    currencies[the_slot]['crypto']=''
    currencies[the_slot]['hold']=0
    currencies[the_slot]['hold']=0
    currencies[the_slot]['new_high']=0
    currencies[the_slot]['spend']=0
    available_slots=available_slots+1

    #back_up values before moving to next currency when several are active but that is not the case now
    #if (currencies[the_slot]!=''):
    #   currencies[the_slot]['buy_price']=buy_price
    #currencies[the_slot]['new_high']=new_high
    #currencies[the_slot]['spend']=spend
    #currencies[the_slot]['hold']=hold
# Out:
# Bot Started!
#
# PURCHASE ORDER:
# date: 2021-12-12 08:03:27.789083
# GALA :$0.57559
#
# sell price if only hits minimum: 0.57559
# will at least need to hit this price to auto sell 0.5873367346938776
# None

# %%
len(product_pool[product])
# Out:
# 89

# %%
#manually sell my current one
#print(auth_client.place_market_order('MASK-USDT', 'sell', size=floor_balance(float(get_balance('MASK')))))
# Out:
# MASK
# {'id': 'f8765463-bde3-4c7c-8c92-4484ba10d156', 'currency': 'MASK', 'balance': '0.9200000000000000', 'hold': '0.0000000000000000', 'available': '0.92', 'profile_id': 'e4ceef7d-bf47-4805-9db1-a65dacc3eb24', 'trading_enabled': True}
# {'id': '52125c98-1635-47c0-b4d3-072c04e125fa', 'size': '0.92', 'product_id': 'MASK-USDT', 'side': 'sell', 'stp': 'dc', 'type': 'market', 'post_only': False, 'created_at': '2021-12-10T03:05:23.87493Z', 'fill_fees': '0', 'filled_size': '0', 'executed_value': '0', 'status': 'pending', 'settled': False}

# %%
#manually buy
#auth_client.place_market_order('BTC-USDT', 'buy', funds=5)
# Out:
# {'id': '2b89d592-6411-45d2-a397-6bc07c39985b',
#  'product_id': 'BTC-USDT',
#  'side': 'buy',
#  'stp': 'dc',
#  'funds': '4.97512437',
#  'specified_funds': '5',
#  'type': 'market',
#  'post_only': False,
#  'created_at': '2021-12-08T21:50:28.975657Z',
#  'fill_fees': '0',
#  'filled_size': '0',
#  'executed_value': '0',
#  'status': 'pending',
#  'settled': False}

# %%
#manually sell 
#a=auth_client.place_market_order('DDX-USDT', 'sell', funds=1)

# %%
k=[1,2,3,4,5]
j=[10,20,30,40,50]

# %%
slope*5.5+intercept
# Out:
# 55.0

# %%
test_df=pd.DataFrame(j,k)

test_df.reset_index(inplace=True)
test_df.columns=['num','score']
test_df
slope, intercept, r_value, p_value, std_err = linregress(test_df['num'], test_df['score'])

regress_values=test_df['score']*slope+intercept
plt.plot(test_df['num'],test_df['score'])
#plt.plot(test_df['score'],regress_values,'-r')
#plt.plot(test_df['score'],regress_values*.96,'-g')
#plt.plot(test_df['score'],regress_values*1.04,'-y')

# %%
test_df=pd.DataFrame(j,k)

test_df.reset_index(inplace=True)
test_df.columns=['num','score']
test_df
slope, intercept, r_value, p_value, std_err = linregress(test_df['num'], test_df['score'])

# %%
a=[0,5]
a.append(10)
a
# Out:
# [0, 5, 10]

# %%
b=a.pop(0)

# %%
a
# Out:
# [5, 10]

# %%
window
# Out:
#      Unnamed: 0  level_0  index                 Date      Open      High  \
# 0             0        0      0  2021-11-16 20:00:00  59893.35  60188.69
# 1             1        1      1  2021-11-16 20:05:00  59979.60  60159.92
# 2             2        2      2  2021-11-16 20:10:00  59837.59  60007.35
# 3             3        3      3  2021-11-16 20:15:00  59600.89  59902.56
# 4             4        4      4  2021-11-16 20:20:00  59708.14  59876.64
# ..          ...      ...    ...                  ...       ...       ...
# 239         239      239    239  2021-11-17 15:55:00  59589.08  59691.16
# 240         240      240    240  2021-11-17 16:00:00  59423.82  59683.72
# 241         241      241    241  2021-11-17 16:05:00  59427.28  59625.56
# 242         242      242    242  2021-11-17 16:10:00  59512.51  59887.98
# 243         243      243    243  2021-11-17 16:15:00  59575.90  60027.37
#
#           Low     Close    Volume
# 0    60188.68  59992.99  0.704041
# 1    59997.95  60030.96  1.263909
# 2    59987.24  59905.54  7.138614
# 3    59902.56  59770.55  3.807446
# 4    59771.78  59711.45  0.899153
# ..        ...       ...       ...
# 239  59591.00  59650.03  0.414862
# 240  59666.23  59439.02  0.305816
# 241  59450.29  59625.56  5.341838
# 242  59600.10  59887.98  1.102823
# 243  59896.96  59592.09  3.215724
#
# [244 rows x 9 columns]

# %%
window
